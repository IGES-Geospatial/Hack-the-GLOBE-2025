# %% [markdown]
# # STEM Enhancement in Earth Science 2025 Summer Internship
#
# **Team:** Virtual - Hack the GLOBE!
#
# **Subteam:** Metadata Augmentation
#
# **Members:** Jordan Tran
#
# **Dataset:** GLOBE Surface Temperature Protocol
#
# **Original Repository:** https://github.com/DerpCake1/Hack-The-Globe-SEES
#
# **Summary:**
# For the past 2 weeks, using a sample of GLOBE's dataset, I explored ways to improve the quality of the dataset through an interpretable flagging system and generating metadata.
#
# #### Exploration:
# In order to improve the surface temperature dataset and make data more avaliable for future researchers, I decided to explore metadata augmentation of the dataset, which introduce new pieces of data that could be used for models or to identify trends not previously obvious with the original set of data.
#
# Country/Continent/Biome data was to enrich the dataset with new information based off the coordinates recieved.
#
# Year/Month/Country Code was generated in order to make future data projects easier with the dataset.
#
# #### Takeaways:
#
# Through this project I learned more about how to use dataframes to generate new data that wasn't explicitly given, the applications for what this new data could be used for, as well as the science behind surface temperature and strategies to classify outliers in our specific dataset.

# %% [markdown]
# # Importing Libraries

# %%
# !pip install pycountry-convert
# Out:
# Requirement already satisfied: pycountry-convert in /Users/andrew/miniforge3/envs/jupyter/lib/python3.12/site-packages (0.7.2)
# Requirement already satisfied: pprintpp>=0.3.0 in /Users/andrew/miniforge3/envs/jupyter/lib/python3.12/site-packages (from pycountry-convert) (0.4.0)
# Requirement already satisfied: pycountry>=16.11.27.1 in /Users/andrew/miniforge3/envs/jupyter/lib/python3.12/site-packages (from pycountry-convert) (24.6.1)
# Requirement already satisfied: pytest>=3.4.0 in /Users/andrew/miniforge3/envs/jupyter/lib/python3.12/site-packages (from pycountry-convert) (8.4.1)
# Requirement already satisfied: pytest-mock>=1.6.3 in /Users/andrew/miniforge3/envs/jupyter/lib/python3.12/site-packages (from pycountry-convert) (3.14.1)
# Requirement already satisfied: pytest-cov>=2.5.1 in /Users/andrew/miniforge3/envs/jupyter/lib/python3.12/site-packages (from pycountry-convert) (6.2.1)
# Requirement already satisfied: repoze.lru>=0.7 in /Users/andrew/miniforge3/envs/jupyter/lib/python3.12/site-packages (from pycountry-convert) (0.7)
# Requirement already satisfied: wheel>=0.30.0 in /Users/andrew/miniforge3/envs/jupyter/lib/python3.12/site-packages (from pycountry-convert) (0.45.1)
# Requirement already satisfied: iniconfig>=1 in /Users/andrew/miniforge3/envs/jupyter/lib/python3.12/site-packages (from pytest>=3.4.0->pycountry-convert) (2.1.0)
# Requirement already satisfied: packaging>=20 in /Users/andrew/miniforge3/envs/jupyter/lib/python3.12/site-packages (from pytest>=3.4.0->pycountry-convert) (24.2)
# Requirement already satisfied: pluggy<2,>=1.5 in /Users/andrew/miniforge3/envs/jupyter/lib/python3.12/site-packages (from pytest>=3.4.0->pycountry-convert) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /Users/andrew/miniforge3/envs/jupyter/lib/python3.12/site-packages (from pytest>=3.4.0->pycountry-convert) (2.19.1)
# Requirement already satisfied: coverage>=7.5 in /Users/andrew/miniforge3/envs/jupyter/lib/python3.12/site-packages (from coverage[toml]>=7.5->pytest-cov>=2.5.1->pycountry-convert) (7.9.2)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# libraries for metadata augmentation
import reverse_geocode
import pycountry_convert as pc
import pyarrow
import geopandas as gpd
import folium

# %% [markdown]
# # Initialize Data
#
# Pandas will convert the original surface temperature parquet into a dataframe that can be used to generate new columns to improve the data.
#
# In order to generate **Biome** data, an external shape file (.shp) along with its helper files must be downloaded. Complete the following steps to generate the biome column.
#
# 1. Download, and unpack the zip file onto your local device. (https://files.worldwildlife.org/wwfcmsprod/files/Publication/file/6kcchn7e3u_official_teow.zip)
# 2. Move ONLY **.dbf, .prj, .shp, .shx** to the current directory.
# 3. When accessing the shape file (see in **biome**), ensure that the file path is where the file is located on your LOCAL device.
# ```
# global_biomes = gpd.read_file("INSERT PATH HERE/wwf_terr_ecos.shp")
# ```

# %%
# Modifies Pandas settings to view only a set amount of rows and columns; used to display only a small subset of values while viewing all columns
pd.options.display.max_columns = 70
pd.options.display.max_rows = 20

# Initializes the dataframe, provides the data types of all columns, and displays the dataset in a table
# IF DOWNLOADED ON LOCAL DEVICE, PLEASE CHANGE THE FILE PATH TO WHERE THE PARQUET IS STORED
df = pd.read_parquet('https://github.com/IGES-Geospatial/Hack-the-GLOBE-2025/raw/refs/heads/main/inputs/mv_surface_temperatures_wide.parquet')
display(df.info())
display(df)

# Percent of missing values per column (WRITTEN BY MARLIN WONG)
pd.options.display.max_rows = 100
missing = df.isnull().mean().sort_values(ascending=False) * 100
print(missing[missing > 0])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 716031 entries, 0 to 716030
# Data columns (total 64 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   st_id                             716031 non-null  Int64
#  1   site_id                           716031 non-null  Int64
#  2   measured_at                       716031 non-null  datetime64[ns]
#  3   protocol_id                       716031 non-null  Int64
#  4   userid                            716031 non-null  Int64
#  5   surface_condition                 584465 non-null  object
#  6   organizationid                    716031 non-null  int64
#  7   usertype                          716031 non-null  Int64
#  8   submission_id                     90065 non-null   Int64
#  9   st_updated_at                     716031 non-null  object
#  10  st_created_at                     716031 non-null  object
#  11  sts_id                            716029 non-null  Int64
#  12  sample_number                     716029 non-null  Int64
#  13  sample_surface_temperature_c      716029 non-null  float64
#  14  sample_snow_depth_mm              168203 non-null  float64
#  15  sample_snow_depth_flag            24625 non-null   string
#  16  version_id                        615633 non-null  Int64
#  17  version                           615633 non-null  Int64
#  18  site_version_activated_at         615633 non-null  object
#  19  version_date                      615633 non-null  object
#  20  site_version_comments             346495 non-null  string
#  21  homogeneous_site_short_length_m   562231 non-null  float64
#  22  homogeneous_site_long_length_m    562212 non-null  float64
#  23  surface_cover_type                552502 non-null  string
#  24  instrument_type                   470984 non-null  string
#  25  protocol_name                     716031 non-null  string
#  26  protocol_model                    716031 non-null  string
#  27  protocol_association_name         716031 non-null  string
#  28  protocol_alt_name                 716031 non-null  string
#  29  protocol_investigation_area       716031 non-null  string
#  30  user_type_description             716031 non-null  string
#  31  submission_comments               9697 non-null    string
#  32  submission_developer_key_id       90060 non-null   Int64
#  33  submission_access_code_id         0 non-null       Int64
#  34  submission_latitude               71165 non-null   float64
#  35  submission_longitude              71165 non-null   float64
#  36  submission_elevation              71165 non-null   float64
#  37  submission_point                  71165 non-null   object
#  38  submission_data                   22607 non-null   object
#  39  protocol_set_name                 71165 non-null   string
#  40  protocol_set_code                 71165 non-null   Int64
#  41  site_name                         716031 non-null  string
#  42  site_activated_at                 715326 non-null  datetime64[ns]
#  43  site_deactivated_at               622 non-null     datetime64[ns]
#  44  site_comments                     171030 non-null  string
#  45  site_latitude                     716031 non-null  float64
#  46  site_longitude                    716031 non-null  float64
#  47  site_elevation                    716031 non-null  float64
#  48  site_elevation_type               231159 non-null  string
#  49  site_location_source              716031 non-null  string
#  50  site_point                        716031 non-null  object
#  51  site_developer_key_id             715326 non-null  Int64
#  52  site_is_citizen_science           716031 non-null  boolean
#  53  site_nickname                     0 non-null       string
#  54  site_true_latitude                84 non-null      float64
#  55  site_true_longitude               84 non-null      float64
#  56  site_true_elevation               84 non-null      float64
#  57  site_true_point                   84 non-null      object
#  58  site_photo_measured_at            94558 non-null   datetime64[ns]
#  59  site_photo_primary_thumb_url      94554 non-null   string
#  60  site_photo_primary_photo_url      94554 non-null   string
#  61  site_photo_photo_data             94558 non-null   string
#  62  developer_key_name                715326 non-null  string
#  63  developer_key_is_citizen_science  715326 non-null  boolean
# dtypes: Int64(14), boolean(2), datetime64[ns](4), float64(13), int64(1), object(9), string(21)
# memory usage: 351.0+ MB
# None
#          st_id  site_id         measured_at  protocol_id     userid  \
# 0         1957    10652 2008-01-21 11:00:00            8         -1
# 1         1957    10652 2008-01-21 11:00:00            8         -1
# 2         1957    10652 2008-01-21 11:00:00            8         -1
# 3         1958    10652 2008-01-22 11:00:00            8         -1
# 4         1958    10652 2008-01-22 11:00:00            8         -1
# ...        ...      ...                 ...          ...        ...
# 716026  166969   318180 2025-03-27 17:40:00            8  107437128
# 716027  166969   318180 2025-03-27 17:40:00            8  107437128
# 716028  166969   318180 2025-03-27 17:40:00            8  107437128
# 716029  166969   318180 2025-03-27 17:40:00            8  107437128
# 716030  166969   318180 2025-03-27 17:40:00            8  107437128
#
#        surface_condition  organizationid  usertype  submission_id  \
# 0                   None          166361        -1           <NA>
# 1                   None          166361        -1           <NA>
# 2                   None          166361        -1           <NA>
# 3                   None          166361        -1           <NA>
# 4                   None          166361        -1           <NA>
# ...                  ...             ...       ...            ...
# 716026               dry       107437161        11       59928075
# 716027               dry       107437161        11       59928075
# 716028               dry       107437161        11       59928075
# 716029               dry       107437161        11       59928075
# 716030               dry       107437161        11       59928075
#
#                      st_updated_at               st_created_at  sts_id  \
# 0       2012-07-03 13:56:42.722429  2012-07-03 13:56:42.722416   12952
# 1       2012-07-03 13:56:42.722429  2012-07-03 13:56:42.722416   12959
# 2       2012-07-03 13:56:42.722429  2012-07-03 13:56:42.722416   12966
# 3       2012-07-03 13:56:42.743904  2012-07-03 13:56:42.743891   12953
# 4       2012-07-03 13:56:42.743904  2012-07-03 13:56:42.743891   12960
# ...                            ...                         ...     ...
# 716026  2025-03-27 18:13:17.113169  2025-03-27 18:13:17.113169  729233
# 716027  2025-03-27 18:13:17.113169  2025-03-27 18:13:17.113169  729234
# 716028  2025-03-27 18:13:17.113169  2025-03-27 18:13:17.113169  729235
# 716029  2025-03-27 18:13:17.113169  2025-03-27 18:13:17.113169  729236
# 716030  2025-03-27 18:13:17.113169  2025-03-27 18:13:17.113169  729237
#
#         sample_number  sample_surface_temperature_c  sample_snow_depth_mm  \
# 0                   1                           6.5                   0.0
# 1                   2                           6.0                   0.0
# 2                   3                           6.5                   0.0
# 3                   1                           6.0                   0.0
# 4                   2                           6.0                   0.0
# ...               ...                           ...                   ...
# 716026              5                          31.9                   NaN
# 716027              6                          32.0                   NaN
# 716028              7                          31.8                   NaN
# 716029              8                          31.5                   NaN
# 716030              9                          32.0                   NaN
#
#        sample_snow_depth_flag  version_id  version  \
# 0                        <NA>        7248        1
# 1                        <NA>        7248        1
# 2                        <NA>        7248        1
# 3                        <NA>        7248        1
# 4                        <NA>        7248        1
# ...                       ...         ...      ...
# 716026                   <NA>       33853        1
# 716027                   <NA>       33853        1
# 716028                   <NA>       33853        1
# 716029                   <NA>       33853        1
# 716030                   <NA>       33853        1
#
#          site_version_activated_at                version_date  \
# 0              2008-01-21 11:00:00         2008-02-05 09:20:51
# 1              2008-01-21 11:00:00         2008-02-05 09:20:51
# 2              2008-01-21 11:00:00         2008-02-05 09:20:51
# 3              2008-01-21 11:00:00         2008-02-05 09:20:51
# 4              2008-01-21 11:00:00         2008-02-05 09:20:51
# ...                            ...                         ...
# 716026  2023-06-14 18:39:37.794328  2023-06-14 18:39:37.794322
# 716027  2023-06-14 18:39:37.794328  2023-06-14 18:39:37.794322
# 716028  2023-06-14 18:39:37.794328  2023-06-14 18:39:37.794322
# 716029  2023-06-14 18:39:37.794328  2023-06-14 18:39:37.794322
# 716030  2023-06-14 18:39:37.794328  2023-06-14 18:39:37.794322
#
#                                     site_version_comments  \
# 0       please replace with Surface Temperature Site C...
# 1       please replace with Surface Temperature Site C...
# 2       please replace with Surface Temperature Site C...
# 3       please replace with Surface Temperature Site C...
# 4       please replace with Surface Temperature Site C...
# ...                                                   ...
# 716026                                               <NA>
# 716027                                               <NA>
# 716028                                               <NA>
# 716029                                               <NA>
# 716030                                               <NA>
#
#         homogeneous_site_short_length_m  homogeneous_site_long_length_m  \
# 0                                  30.0                            30.0
# 1                                  30.0                            30.0
# 2                                  30.0                            30.0
# 3                                  30.0                            30.0
# 4                                  30.0                            30.0
# ...                                 ...                             ...
# 716026                             53.0                            50.0
# 716027                             53.0                            50.0
# 716028                             53.0                            50.0
# 716029                             53.0                            50.0
# 716030                             53.0                            50.0
#
#        surface_cover_type instrument_type        protocol_name  \
# 0             short grass     raytek st20  Surface Temperature
# 1             short grass     raytek st20  Surface Temperature
# 2             short grass     raytek st20  Surface Temperature
# 3             short grass     raytek st20  Surface Temperature
# 4             short grass     raytek st20  Surface Temperature
# ...                   ...             ...                  ...
# 716026            asphalt        Etekcity  Surface Temperature
# 716027            asphalt        Etekcity  Surface Temperature
# 716028            asphalt        Etekcity  Surface Temperature
# 716029            asphalt        Etekcity  Surface Temperature
# 716030            asphalt        Etekcity  Surface Temperature
#
#             protocol_model protocol_association_name    protocol_alt_name  \
# 0       SurfaceTemperature       surface_temperature  Surface Temperature
# 1       SurfaceTemperature       surface_temperature  Surface Temperature
# 2       SurfaceTemperature       surface_temperature  Surface Temperature
# 3       SurfaceTemperature       surface_temperature  Surface Temperature
# 4       SurfaceTemperature       surface_temperature  Surface Temperature
# ...                    ...                       ...                  ...
# 716026  SurfaceTemperature       surface_temperature  Surface Temperature
# 716027  SurfaceTemperature       surface_temperature  Surface Temperature
# 716028  SurfaceTemperature       surface_temperature  Surface Temperature
# 716029  SurfaceTemperature       surface_temperature  Surface Temperature
# 716030  SurfaceTemperature       surface_temperature  Surface Temperature
#
#        protocol_investigation_area       user_type_description  \
# 0                       Atmosphere             not categorized
# 1                       Atmosphere             not categorized
# 2                       Atmosphere             not categorized
# 3                       Atmosphere             not categorized
# 4                       Atmosphere             not categorized
# ...                            ...                         ...
# 716026                  Atmosphere  non-student user - trained
# 716027                  Atmosphere  non-student user - trained
# 716028                  Atmosphere  non-student user - trained
# 716029                  Atmosphere  non-student user - trained
# 716030                  Atmosphere  non-student user - trained
#
#        submission_comments  submission_developer_key_id  \
# 0                     <NA>                         <NA>
# 1                     <NA>                         <NA>
# 2                     <NA>                         <NA>
# 3                     <NA>                         <NA>
# 4                     <NA>                         <NA>
# ...                    ...                          ...
# 716026                <NA>                            5
# 716027                <NA>                            5
# 716028                <NA>                            5
# 716029                <NA>                            5
# 716030                <NA>                            5
#
#         submission_access_code_id  submission_latitude  submission_longitude  \
# 0                            <NA>                  NaN                   NaN
# 1                            <NA>                  NaN                   NaN
# 2                            <NA>                  NaN                   NaN
# 3                            <NA>                  NaN                   NaN
# 4                            <NA>                  NaN                   NaN
# ...                           ...                  ...                   ...
# 716026                       <NA>            40.117903            -83.160308
# 716027                       <NA>            40.117903            -83.160308
# 716028                       <NA>            40.117903            -83.160308
# 716029                       <NA>            40.117903            -83.160308
# 716030                       <NA>            40.117903            -83.160308
#
#         submission_elevation  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 716026                 279.5
# 716027                 279.5
# 716028                 279.5
# 716029                 279.5
# 716030                 279.5
#
#                                          submission_point submission_data  \
# 0                                                    None            None
# 1                                                    None            None
# 2                                                    None            None
# 3                                                    None            None
# 4                                                    None            None
# ...                                                   ...             ...
# 716026  01010000A0E610000061527C7C42CA54C0D68C0C72170F...            None
# 716027  01010000A0E610000061527C7C42CA54C0D68C0C72170F...            None
# 716028  01010000A0E610000061527C7C42CA54C0D68C0C72170F...            None
# 716029  01010000A0E610000061527C7C42CA54C0D68C0C72170F...            None
# 716030  01010000A0E610000061527C7C42CA54C0D68C0C72170F...            None
#
#           protocol_set_name  protocol_set_code             site_name  \
# 0                      <NA>               <NA>  Gim7RZ/PL/143:ATM189
# 1                      <NA>               <NA>  Gim7RZ/PL/143:ATM189
# 2                      <NA>               <NA>  Gim7RZ/PL/143:ATM189
# 3                      <NA>               <NA>  Gim7RZ/PL/143:ATM189
# 4                      <NA>               <NA>  Gim7RZ/PL/143:ATM189
# ...                     ...                ...                   ...
# 716026  Surface Temperature               9808   asphalt parking lot
# 716027  Surface Temperature               9808   asphalt parking lot
# 716028  Surface Temperature               9808   asphalt parking lot
# 716029  Surface Temperature               9808   asphalt parking lot
# 716030  Surface Temperature               9808   asphalt parking lot
#
#        site_activated_at site_deactivated_at    site_comments  site_latitude  \
# 0             2008-01-31                 NaT             <NA>      50.146600
# 1             2008-01-31                 NaT             <NA>      50.146600
# 2             2008-01-31                 NaT             <NA>      50.146600
# 3             2008-01-31                 NaT             <NA>      50.146600
# 4             2008-01-31                 NaT             <NA>      50.146600
# ...                  ...                 ...              ...            ...
# 716026        2023-06-14                 NaT  Asphalt Parking      40.117903
# 716027        2023-06-14                 NaT  Asphalt Parking      40.117903
# 716028        2023-06-14                 NaT  Asphalt Parking      40.117903
# 716029        2023-06-14                 NaT  Asphalt Parking      40.117903
# 716030        2023-06-14                 NaT  Asphalt Parking      40.117903
#
#         site_longitude  site_elevation site_elevation_type  \
# 0            22.173800           179.1         ellipsoidal
# 1            22.173800           179.1         ellipsoidal
# 2            22.173800           179.1         ellipsoidal
# 3            22.173800           179.1         ellipsoidal
# 4            22.173800           179.1         ellipsoidal
# ...                ...             ...                 ...
# 716026      -83.160308           279.5                <NA>
# 716027      -83.160308           279.5                <NA>
# 716028      -83.160308           279.5                <NA>
# 716029      -83.160308           279.5                <NA>
# 716030      -83.160308           279.5                <NA>
#
#        site_location_source  \
# 0                       gps
# 1                       gps
# 2                       gps
# 3                       gps
# 4                       gps
# ...                     ...
# 716026                other
# 716027                other
# 716028                other
# 716029                other
# 716030                other
#
#                                                site_point  \
# 0       01010000A0E6100000780B24287E2C3640FBCBEEC9C312...
# 1       01010000A0E6100000780B24287E2C3640FBCBEEC9C312...
# 2       01010000A0E6100000780B24287E2C3640FBCBEEC9C312...
# 3       01010000A0E6100000780B24287E2C3640FBCBEEC9C312...
# 4       01010000A0E6100000780B24287E2C3640FBCBEEC9C312...
# ...                                                   ...
# 716026  01010000A0E610000061527C7C42CA54C0D68C0C72170F...
# 716027  01010000A0E610000061527C7C42CA54C0D68C0C72170F...
# 716028  01010000A0E610000061527C7C42CA54C0D68C0C72170F...
# 716029  01010000A0E610000061527C7C42CA54C0D68C0C72170F...
# 716030  01010000A0E610000061527C7C42CA54C0D68C0C72170F...
#
#         site_developer_key_id  site_is_citizen_science site_nickname  \
# 0                           1                    False          <NA>
# 1                           1                    False          <NA>
# 2                           1                    False          <NA>
# 3                           1                    False          <NA>
# 4                           1                    False          <NA>
# ...                       ...                      ...           ...
# 716026                      1                    False          <NA>
# 716027                      1                    False          <NA>
# 716028                      1                    False          <NA>
# 716029                      1                    False          <NA>
# 716030                      1                    False          <NA>
#
#         site_true_latitude  site_true_longitude  site_true_elevation  \
# 0                      NaN                  NaN                  NaN
# 1                      NaN                  NaN                  NaN
# 2                      NaN                  NaN                  NaN
# 3                      NaN                  NaN                  NaN
# 4                      NaN                  NaN                  NaN
# ...                    ...                  ...                  ...
# 716026                 NaN                  NaN                  NaN
# 716027                 NaN                  NaN                  NaN
# 716028                 NaN                  NaN                  NaN
# 716029                 NaN                  NaN                  NaN
# 716030                 NaN                  NaN                  NaN
#
#        site_true_point site_photo_measured_at site_photo_primary_thumb_url  \
# 0                 None                    NaT                         <NA>
# 1                 None                    NaT                         <NA>
# 2                 None                    NaT                         <NA>
# 3                 None                    NaT                         <NA>
# 4                 None                    NaT                         <NA>
# ...                ...                    ...                          ...
# 716026            None                    NaT                         <NA>
# 716027            None                    NaT                         <NA>
# 716028            None                    NaT                         <NA>
# 716029            None                    NaT                         <NA>
# 716030            None                    NaT                         <NA>
#
#        site_photo_primary_photo_url site_photo_photo_data  \
# 0                              <NA>                  <NA>
# 1                              <NA>                  <NA>
# 2                              <NA>                  <NA>
# 3                              <NA>                  <NA>
# 4                              <NA>                  <NA>
# ...                             ...                   ...
# 716026                         <NA>                  <NA>
# 716027                         <NA>                  <NA>
# 716028                         <NA>                  <NA>
# 716029                         <NA>                  <NA>
# 716030                         <NA>                  <NA>
#
#                 developer_key_name  developer_key_is_citizen_science
# 0       GLOBE Data Entry Web Forms                             False
# 1       GLOBE Data Entry Web Forms                             False
# 2       GLOBE Data Entry Web Forms                             False
# 3       GLOBE Data Entry Web Forms                             False
# 4       GLOBE Data Entry Web Forms                             False
# ...                            ...                               ...
# 716026  GLOBE Data Entry Web Forms                             False
# 716027  GLOBE Data Entry Web Forms                             False
# 716028  GLOBE Data Entry Web Forms                             False
# 716029  GLOBE Data Entry Web Forms                             False
# 716030  GLOBE Data Entry Web Forms                             False
#
# [716031 rows x 64 columns]
# submission_access_code_id           100.000000
# site_nickname                       100.000000
# site_true_point                      99.988269
# site_true_elevation                  99.988269
# site_true_longitude                  99.988269
# site_true_latitude                   99.988269
# site_deactivated_at                  99.913132
# submission_comments                  98.645729
# submission_data                      96.842734
# sample_snow_depth_flag               96.560903
# submission_point                     90.061185
# submission_elevation                 90.061185
# submission_longitude                 90.061185
# submission_latitude                  90.061185
# protocol_set_name                    90.061185
# protocol_set_code                    90.061185
# submission_developer_key_id          87.422332
# submission_id                        87.421634
# site_photo_primary_photo_url         86.794706
# site_photo_primary_thumb_url         86.794706
# site_photo_measured_at               86.794147
# site_photo_photo_data                86.794147
# sample_snow_depth_mm                 76.508978
# site_comments                        76.114163
# site_elevation_type                  67.716621
# site_version_comments                51.608939
# instrument_type                      34.222960
# surface_cover_type                   22.838257
# homogeneous_site_long_length_m       21.482170
# homogeneous_site_short_length_m      21.479517
# surface_condition                    18.374344
# version                              14.021460
# site_version_activated_at            14.021460
# version_id                           14.021460
# version_date                         14.021460
# site_activated_at                     0.098459
# site_developer_key_id                 0.098459
# developer_key_name                    0.098459
# developer_key_is_citizen_science      0.098459
# sts_id                                0.000279
# sample_number                         0.000279
# sample_surface_temperature_c          0.000279
# dtype: float64

# %% [markdown]
# # Metadata Augmentation
#
# Metadata augmentation uses the provided data and generates new data that can be used to improve future models and provide more information about a given datapoint.
#
# Columns were added for the purposes of providing information that wasn't previously given in dataset, as well as making avaliable information easier to access for future data projects.
#
# Metadata added:
# - Countries
# - Country Code
# - Continent
# - Year
# - Month
# - Biome

# %% [markdown]
# ### Country / Country Code / Continent
#
# Useful to compare surface temperature for country, i.e (avg surface temp of 1 country vs. another)

# %%
# uses an offline library to reverse geocode the country that data was taken in through its site latitude and longitude.
# MISSING DATA RETURNS "" FOR BOTH COUNTRY AND COUNTRY CODE
def reverse_geo(lat, lon):
    if pd.isna(lat) or pd.isna(lon):
        return None, None

    coords = [(lat, lon)]
    # Perform reverse geocoding
    location = reverse_geocode.search(coords)
    
    # Extract country information
    if location:
        return location[0].get("country"), location[0].get("country_code")
    else:
        return "", ""

# function that takes a given row's latitude and longitude in order to use .apply and make a new column with countries
def get_country_from_row(row):
    lat = row['site_latitude']
    lon = row['site_longitude']
    return reverse_geo(lat, lon)


reverse_geo(37.698551,-122.073959) # test case
df[["country", 'country_code']] = df.apply(get_country_from_row, axis=1, result_type='expand')
display(df["country_code"])
# Out:
# 0         PL
# 1         PL
# 2         PL
# 3         PL
# 4         PL
#           ..
# 716026    US
# 716027    US
# 716028    US
# 716029    US
# 716030    US
# Name: country_code, Length: 716031, dtype: object

# %%
# uses pycountry_convert to turn a country name into its respective continent
# MISSING DATA RETURNS "" FOR CONTINENT
def country_to_continent(country):
    try:
        country_alpha2 = pc.country_name_to_country_alpha2(country)
        country_continent_code = pc.country_alpha2_to_continent_code(country_alpha2)
        country_continent_name = pc.convert_continent_code_to_continent_name(country_continent_code)
        return country_continent_name
    except:
        return ""

def get_cont_from_row(row):
    return country_to_continent(row["country"])

print(country_to_continent("Poland")) # test case
df["continent"] = df.apply(get_cont_from_row, axis=1)
display(df["continent"])
# Out:
# Europe
# 0                Europe
# 1                Europe
# 2                Europe
# 3                Europe
# 4                Europe
#               ...
# 716026    North America
# 716027    North America
# 716028    North America
# 716029    North America
# 716030    North America
# Name: continent, Length: 716031, dtype: object

# %% [markdown]
# ### Year / Month

# %%
# "Measured_at" is in datetime64[ns], which year and month can be extracted from through pandas
df['year'] = df['measured_at'].dt.year
df['month'] = df['measured_at'].dt.month
display(df['month'])
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 716026    3
# 716027    3
# 716028    3
# 716029    3
# 716030    3
# Name: month, Length: 716031, dtype: int32

# %% [markdown]
# ### Biomes
#
# The global biome data is sourced from World Wildlife Fund's (WWF) Terrestrial Ecoregions of the World.
#
# DOI: https://doi.org/10.1641/0006-3568(2001)051[0933:TEOTWA]2.0.CO;2
#
# WWF's Publication: https://www.worldwildlife.org/publications/terrestrial-ecoregions-of-the-world
#
# Download URL: https://files.worldwildlife.org/wwfcmsprod/files/Publication/file/6kcchn7e3u_official_teow.zip

# %%
# Creates polygons out of WWF's .shp file, and overlays site coordinates over it to determine each point's biome
global_biomes = gpd.read_file("https://github.com/IGES-Geospatial/Hack-the-GLOBE-2025/raw/refs/heads/main/inputs/custom/wwf/wwf_terr_ecos.shp")

# turns site coordinates into 'Point' datatypes for geopanadas
points = gpd.points_from_xy(df['site_longitude'],df["site_latitude"])

gdf = gpd.GeoDataFrame(df, geometry=points, crs="EPSG:4326")

biomes = global_biomes.to_crs("EPSG:4326")

# creates a new dataframe which intersects the original dataframe with the geopandas one
result = gpd.sjoin(gdf, biomes, how="left", predicate='intersects')
df['biome'] = result["ECO_NAME"]

# %%
# Return the dataframe back to a parquet that is exported to the 'outputs' directory for future use
df.to_parquet("../outputs/JordanTran_Output.parquet")
